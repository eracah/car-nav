# %%
import gym
from matplotlib import pyplot as plt
# %matplotlib inline
from car_env import CarNav

# %%
UP, DOWN, LEFT, RIGHT = range(4)

actions =  [RIGHT,RIGHT,RIGHT, UP,UP,UP,UP, LEFT,LEFT,LEFT,LEFT,LEFT]

env = CarNav(step_size=32)

obs = env.reset()
plt.imshow(obs)
plt.axis("off")
plt.show()
reward = 0
for action in actions:
    obs, reward, done, _ = env.step(action)
    print("Action taken was {}".format(env.action_meanings[action]))
    print("Reward is: {}".format(reward))
    print("Done is: {}".format(done))
    plt.imshow(obs)
    plt.axis("off")
    plt.show()
# Out:
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was up
# Reward is: 0
# Done is: False
# Action taken was up
# Reward is: 0
# Done is: False
# Action taken was up
# Reward is: 0
# Done is: False
# Action taken was up
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 4
# Done is: True

# %%
actions =  [LEFT,LEFT, LEFT,DOWN,DOWN,DOWN,RIGHT,RIGHT,RIGHT,RIGHT,RIGHT]

env = CarNav(step_size=32)

obs = env.reset()
plt.imshow(obs)
plt.axis("off")
plt.show()
reward = 0
for action in actions:
    obs, reward, done, _ = env.step(action)
    print("Action taken was {}".format(env.action_meanings[action]))
    print("Reward is: {}".format(reward))
    print("Done is: {}".format(done))
    plt.imshow(obs)
    plt.axis("off")
    plt.show()
# Out:
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was left
# Reward is: 0
# Done is: False
# Action taken was down
# Reward is: 0
# Done is: False
# Action taken was down
# Reward is: 0
# Done is: False
# Action taken was down
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 0
# Done is: False
# Action taken was right
# Reward is: 2
# Done is: True

# %%
actions =  [RIGHT,RIGHT,RIGHT, UP,UP,UP,UP, LEFT,LEFT,LEFT,LEFT,LEFT]

env = CarNav(step_size=32,game_id=1)

obs = env.reset()
reward = 0
for action in actions:
    obs, reward, done, _ = env.step(action)
    print("Action taken was {}".format(env.action_meanings[action]))
    print("Reward is: {}".format(reward))
    plt.imshow(obs)
    plt.axis("off")
    plt.show()
# Out:
# Action taken was right
# Reward is: 0
# Action taken was right
# Reward is: 0
# Action taken was right
# Reward is: 0
# Action taken was up
# Reward is: 0
# Action taken was up
# Reward is: 0
# Action taken was up
# Reward is: 0
# Action taken was up
# Reward is: 0
# Action taken was left
# Reward is: 0
# Action taken was left
# Reward is: 0
# Action taken was left
# Reward is: 0
# Action taken was left
# Reward is: 0
# Action taken was left
# Reward is: 0
